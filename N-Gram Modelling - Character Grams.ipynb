# %%
import random

# %%
# Sample data
text = """Global warming or climate change has become a worldwide concern. It is gradually developing into an unprecedented environmental crisis evident in melting glaciers, changing weather patterns, rising sea levels, floods, cyclones and droughts. Global warming implies an increase in the average temperature of the Earth due to entrapment of greenhouse gases in the earth’s atmosphere."""

# %%
n = 3 # trigrams

# %%
# Our N-Grams dictionary
ngrams = {}

# %%
# Creating the n-gram

for i in range(len(text)-n):
    gram = text[i:i+n]   
    if gram not in ngrams.keys():
        ngrams[gram] = []
    ngrams[gram].append(text[i+n])

# %%
# in 1st iteration . text[0 :3]-- glo
# if this is not in ngrams dictionary, then add it to ngrams list
# to this list append the text [i+3] , here append the character that follows glo i.e b and nywhere in text that follows glo.

# %%
ngrams  # trigrams with list of characters that follow the trigram
# Out:
# {'Glo': ['b', 'b'],
#  'lob': ['a', 'a'],
#  'oba': ['l', 'l'],
#  'bal': [' ', ' '],
#  'al ': ['w', 'c', 'w'],
#  'l w': ['a', 'a'],
#  ' wa': ['r', 'r'],
#  'war': ['m', 'm'],
#  'arm': ['i', 'i'],
#  'rmi': ['n', 'n'],
#  'min': ['g', 'g'],
#  'ing': [' ', ' ', ' ', ' ', ' ', ' '],
#  'ng ': ['o', 'i', 'g', 'w', 's', 'i'],
#  'g o': ['r'],
#  ' or': [' '],
#  'or ': ['c'],
#  'r c': ['l'],
#  ' cl': ['i'],
#  'cli': ['m'],
#  'lim': ['a'],
#  'ima': ['t'],
#  'mat': ['e'],
#  'ate': [' '],
#  'te ': ['c'],
#  'e c': ['h', 'o'],
#  ' ch': ['a', 'a'],
#  'cha': ['n', 'n'],
#  'han': ['g', 'g'],
#  'ang': ['e', 'i'],
#  'nge': [' '],
#  'ge ': ['h', 't'],
#  'e h': ['a'],
#  ' ha': ['s'],
#  'has': [' '],
#  'as ': ['b'],
#  's b': ['e'],
#  ' be': ['c'],
#  'bec': ['o'],
#  'eco': ['m'],
#  'com': ['e'],
#  'ome': [' '],
#  'me ': ['a'],
#  'e a': [' ', 'v'],
#  ' a ': ['w'],
#  'a w': ['o'],
#  ' wo': ['r'],
#  'wor': ['l'],
#  'orl': ['d'],
#  'rld': ['w'],
#  'ldw': ['i'],
# ...

# %%
# Testing our N-Gram Model 

currentGram = text[0:n]
result = currentGram
for i in range(100):
    if currentGram not in ngrams.keys():
        break
    possibilities = ngrams[currentGram]
    nextItem = possibilities[random.randrange(len(possibilities))]
    result += nextItem
    currentGram = result[len(result)-n:len(result)]
  
print(result)
# Out:
# Global warming or climate concern. It is evide concern. It into ent of greenhouse gase gase gase in the

# %%
# possibilities is list of all characters that folows that currentgram which we give

# randrange -- returns random element from that list  between o and length of list of items
# for example: for glo, we have b, b in list 

# we take the last 3 characters from the list in current gram len(list) - 3 to the last one. 
# last 3 characters from the list

# %%
# change n=6 and rerun. it gives good o/p with meaning
